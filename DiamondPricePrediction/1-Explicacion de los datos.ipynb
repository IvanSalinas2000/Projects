# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanSalinas2000/Aprendizaje-automatico/blob/main/Tareas/Tarea1DefinirDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tarea Definir un conjunto de datos

# %% [markdown]
# ##Justificacion y explicacion de datos

# %% [markdown]
# El conjunto de datos con el que se trabajara durante el curso sera un dataset con datos que se han juntado de diamntes y sus diferentes caracteristicas, las cuales son:
#
# Price: En el caso del precio de los diamantes, puede variar de forma continua, desde valores muy bajos hasta valores muy altos, sin límites específicos y con una infinidad de posibilidades entre ellos.
#
#
# Carat: Son los quilates, el cual representa a 1 quilate = 0.2 gramos
#
# Color: Cut: Es la calidad de corte en el diamante que son Fair, Good, Very Good, Premium e Ideal. Se piensa que es importante por la importancia que puede tener un buen trabajo realizado por el artesano que corto el diamante.
#
# Color: El color se clasifica desde la J a la D, lo cual nos indica que tan incoloro es el diamante,
# conforme más bajo sea su escala tiene un color cercano al amarillo. Esto se considera importante
# para el precio ya que nos indica la pureza del diamante.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Clarity: Es una medida de qué tan claro es el diamante (I1 (peor), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (mejor)). Se piensa que es importante ya que los diamantes al ser creados bajo altas temperaturas y presiones pueden llegar a tener burbujas o imperfecciones dentro y eso se piensa que afecta el precio de este mismo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Table: Ancho de la parte superior del diamante en relación con el punto más ancho (43-95). Se piensa que es importante en relación con el precio ya que es lo que le da la forma característica de diamante una
# buena proporción de ancho de mesa.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego tenemos las variables x y z las cuales representan el tamaño de las dimensiones del diamante.
#
# X longitud en mm (0-10.74)
#
# Y ancho en mm (0-58.9)
#
# Z profundidad en mm (0-31.8)
#
# La importancia de estas variables es vital ya que son las que nos describen las dimensiones del diamante mismo, por lo que un diamante con mayores dimensiones podría ser el que tenga mayor precio.

# %% [markdown]
# ##Objetivos

# %% [markdown]
# Se desea dar a conocer la forma en la que se llega al valor que recibe un diamante basándose en las
# características de este mismo y como pueden llegar a ser mas importantes que otras. De esta manera se quiere llegar a una conclusión donde se pueda apreciar la importancia de sus dimensiones, su diseño o pureza.

# %% [markdown]
# ##Fuente de los datos

# %% [markdown]
# https://www.kaggle.com/datasets/shivam2503/diamonds/data
